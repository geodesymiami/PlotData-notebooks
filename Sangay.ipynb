# %%
import os
import sys
import plotdata.cli.viewPS as viewPS
import plotdata.cli.plot_data as plot_data
from mintpy.cli import tsview, view
from IPython.display import clear_output
os.chdir(os.getenv('SCRATCHDIR'))
# !pwd
# Out:
# /Users/giacomo/Library/CloudStorage/OneDrive-UniversityofMiami/scratch

# %%
# %%capture --no-display
# %tb
EXAMPLE='''
plot_data.py SangaySenDT142/mintpy SangaySenAT18/mintpy --plot-type velocity --dem SangaySenDT142/dem/Sangay_dem.tif --mask-thresh 0.55 --style scatter --scatter-size 8 --shade-exag 0.01
'''
lines = EXAMPLE.splitlines()
os.chdir(os.getenv('SCRATCHDIR'))
for line in lines[1:]:
    line = line.strip()
    cmd=line.strip().split(' ')
    sys.argv = cmd
    plot_data.main(sys.argv)

# %%
# %%capture --no-display
# %matplotlib widget
scratch = os.getenv('SCRATCHDIR')

ts_file = os.path.expanduser(scratch + '/SangaySenDT142/mintpy/S1_IW23_142_0600_0602_20170102_XXXXXXXX.he5')
cmd = f'{ts_file} --yx 280 270 --figsize 9 4 --dem {scratch}/SangaySenDT142/dem/Sangay_dem.tif --shade-exag 0.01'
tsview.main(cmd.split())
