# %%
import os
import sys
import plotdata.cli.viewPS as viewPS
import plotdata.cli.plot_data as plot_data
from mintpy.cli import tsview
os.chdir(os.getenv('SCRATCHDIR'))
# !pwd
desc = 'ArjunoWelirangSenDT3'
asc = 'ArjunoWelirangSenAT54'
min_desc = desc + '/mintpy'
min_asc = asc + '/mintpy'
delau_desc = desc + '/miaplpy/network_delaunay'
delau_asc = asc + '/miaplpy/network_delaunay'
# Out:
# /Users/giacomo/Library/CloudStorage/OneDrive-UniversityofMiami/scratch

# %%
# %%capture --no-display
# %tb
EXAMPLE=f'''
plot_data.py {min_desc} {min_asc} --plot-type velocity --mask-thresh 0.7 --dem {desc}/dem/ArjunoWelirang_dem.tif --vlim -1.5 1.5 --style scatter --scatter-size 8 --shade-exag 0.01
'''
lines = EXAMPLE.splitlines()
os.chdir(os.getenv('SCRATCHDIR'))
for line in lines[1:]:
    line = line.strip()
    cmd=line.strip().split(' ')
    sys.argv = cmd
    plot_data.main(sys.argv)

# %%
# %%capture --no-display
# %tb
EXAMPLE=f'''
plot_data.py {delau_desc} {delau_asc} --plot-type velocity --mask-thresh 0.7 --dem {desc}/dem/ArjunoWelirang_dem.tif --vlim -1.5 1.5 --style scatter --scatter-size 8 --shade-exag 0.01
'''
lines = EXAMPLE.splitlines()
os.chdir(os.getenv('SCRATCHDIR'))
for line in lines[1:]:
    line = line.strip()
    cmd=line.strip().split(' ')
    sys.argv = cmd
    plot_data.main(sys.argv)
