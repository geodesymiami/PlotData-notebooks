# %%
import os
import sys
import plotdata.cli.viewPS as viewPS
import plotdata.cli.plot_data as plot_data
from mintpy.cli import tsview, view
from IPython.display import clear_output
os.chdir(os.getenv('SCRATCHDIR'))
# !pwd
# Out:
# /Users/giacomo/Library/CloudStorage/OneDrive-UniversityofMiami/scratch

# %%
# %%capture --no-display
# %tb
EXAMPLE='''
plot_data.py WolfSenDT128/mintpy WolfSenAT106/mintpy --plot-type velocity --dem WolfSenAT106/dem/Wolf_dem.tif --mask-thresh 0.55 --style scatter --scatter-size 8 --shade-exag 0.01
'''
lines = EXAMPLE.splitlines()
os.chdir(os.getenv('SCRATCHDIR'))
for line in lines[1:]:
    line = line.strip()
    cmd=line.strip().split(' ')
    sys.argv = cmd
    plot_data.main(sys.argv)

# %%
# %%capture --no-display
# %matplotlib widget
scratch = os.getenv('SCRATCHDIR')

ts_file = os.path.expanduser(scratch + '/WolfSenDT128/mintpy/S1_IW12_128_0593_0594_20170107_XXXXXXXX.he5')
cmd = f'{ts_file} --yx 220 270 --figsize 9 4 --dem {scratch}/WolfSenDT128/dem/Wolf_dem.tif --shade-exag 0.01 --ref-lalo -0.07 -91.37'
tsview.main(cmd.split())

# %%
# %%capture --no-display
# %matplotlib widget
scratch = os.getenv('SCRATCHDIR')

ts_file = os.path.expanduser(scratch + '/WolfSenAT106/mintpy/S1_IW3_106_1180_1181_20170106_XXXXXXXX.he5')
cmd = f'{ts_file} --yx 170 200 --figsize 9 4 --dem {scratch}/WolfSenAT106/dem/Wolf_dem.tif --shade-exag 0.01 --ref-lalo -0.07 -91.37'
tsview.main(cmd.split())

# %% [markdown]
# # Miaplpy

# %%
# %%capture --no-display
# %tb
EXAMPLE='''
plot_data.py WolfSenDT128/miaplpy/network_delaunay WolfSenAT106/miaplpy/network_delaunay --plot-type velocity --dem WolfSenAT106/dem/Wolf_dem.tif --mask-thresh 0.55 --style scatter --scatter-size 8 --shade-exag 0.01
'''
lines = EXAMPLE.splitlines()
os.chdir(os.getenv('SCRATCHDIR'))
for line in lines[1:]:
    line = line.strip()
    cmd=line.strip().split(' ')
    sys.argv = cmd
    plot_data.main(sys.argv)
