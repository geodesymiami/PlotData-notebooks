# %%
import os
import sys
import plotdata.cli.viewPS as viewPS
import plotdata.cli.plot_data as plot_data
from mintpy.cli import tsview, view
from IPython.display import clear_output
os.chdir(os.getenv('SCRATCHDIR'))
# !pwd
# Out:
# /Users/giacomo/Library/CloudStorage/OneDrive-UniversityofMiami/scratch

# %%
# %%capture --no-display
# %tb
EXAMPLE='''
plot_data.py CerroNegroSenDT55/mintpy CerroNegroSenAT165/mintpy --plot-type velocity --dem CerroNegroSenDT55/DEM/CerroNegro_dem.tif --mask-thresh 0.55 --vlim -3 3 --style scatter --scatter-size 4 --shade-exag 0.01
'''
lines = EXAMPLE.splitlines()
os.chdir(os.getenv('SCRATCHDIR'))
for line in lines[1:]:
    line = line.strip()
    cmd=line.strip().split(' ')
    sys.argv = cmd
    plot_data.main(sys.argv)

# %%
# %%capture --no-display
# %matplotlib widget
scratch = os.getenv('SCRATCHDIR')

ts_file = os.path.expanduser(scratch + '/CerroNegroSenDT55/mintpy/S1_IW1_055_0552_0553_20200111_XXXXXXXX.he5')
cmd = f'{ts_file} --yx 126 140 --figsize 9 4 --dem {scratch}/CerroNegroSenDT55/DEM/CerroNegro_dem.tif --shade-exag 0.01'
tsview.main(cmd.split())

# %%
# %%capture --no-display
# clear_output()
file = os.path.expanduser(scratch + '/CerroNegroSenAT165/mintpy/S1_IW12_165_0038_0039_20200106_XXXXXXXX.he5')
cmd = f'{file} --yx 124 140 --figsize 9 4 --dem {scratch}/CerroNegroSenDT55/DEM/CerroNegro_dem.tif --shade-exag 0.01'
tsview.main(cmd.split())

# %%
# %%capture --no-display
# %tb
EXAMPLE='''
plot_data.py CerroNegroSenDT55/miaplpy/network_delaunay CerroNegroSenAT165/miaplpy/network_delaunay --plot-type velocity --dem CerroNegroSenDT55/DEM/CerroNegro_dem.tif --mask-thresh 0.55 --style scatter --scatter-size 4 --shade-exag 0.01
'''
lines = EXAMPLE.splitlines()
os.chdir(os.getenv('SCRATCHDIR'))
for line in lines[1:]:
    line = line.strip()
    cmd=line.strip().split(' ')
    sys.argv = cmd
    plot_data.main(sys.argv)

# %%
# %%capture --no-display
# %matplotlib widget
scratch = os.getenv('SCRATCHDIR')

ts_file = os.path.expanduser(scratch + '/CerroNegroSenDT55/miaplpy/network_delaunay/S1_IW1_055_0552_0553_20200111_XXXXXXXX.he5')
cmd = f'{ts_file} --yx 87 103 --figsize 9 4 --dem {scratch}/CerroNegroSenDT55/DEM/CerroNegro_dem.tif --shade-exag 0.01'
tsview.main(cmd.split())

# %%
# %%capture --no-display
# %matplotlib widget
scratch = os.getenv('SCRATCHDIR')

ts_file = os.path.expanduser(scratch + '/CerroNegroSenAT165/miaplpy/network_delaunay/S1_IW12_165_0038_0039_20200106_XXXXXXXX.he5')
cmd = f'{ts_file} --yx 87 103 --figsize 9 4 --dem {scratch}/CerroNegroSenDT55/DEM/CerroNegro_dem.tif --shade-exag 0.01'
tsview.main(cmd.split())
