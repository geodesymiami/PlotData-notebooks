# %% [markdown]
# ## Summary Miami
# This notebook demonstrates the examples of `viewPS.py`. For running, make sure you area in a directory with data.

# %%
import os
import sys
import plotdata.cli.viewPS as viewPS
from plotdata.cli.viewPS import EXAMPLE

# %%
lines = EXAMPLE.splitlines()
os.chdir(os.getenv('SCRATCHDIR') + '/MiamiSenAT48/miaplpy_MDCBeach_201601_202310/network_delaunay_4')
for line in lines[1:]:
    print(line)
    cmd=line.strip().split(' ')
    sys.argv = cmd
    viewPS.main(sys.argv)
# Out:
#             viewPS.py S1*PS.he5 --subset-lalo 25.8759:25.8787,-80.1223:-80.1205
# 20240203:004537 * viewPS.py S1*PS.he5 --subset-lalo 25.8759:25.8787,-80.1223:-80.1205
#             viewPS.py S1*PS.he5 displacement --subset-lalo 25.8759:25.8787,-80.1223:-80.1205 --ref-lalo 25.876026 -80.122124
# 20240203:004540 * viewPS.py S1*PS.he5 displacement --subset-lalo 25.8759:25.8787,-80.1223:-80.1205 --ref-lalo 25.876026 -80.122124
#             viewPS.py S1*PS.he5 displacement --subset-lalo 25.8759:25.8787,-80.1223:-80.1205 --ref-lalo 25.876026 -80.122124 --mask ../maskPS.h5
# 20240203:004541 * viewPS.py S1*PS.he5 displacement --subset-lalo 25.8759:25.8787,-80.1223:-80.1205 --ref-lalo 25.876026 -80.122124 --mask ../maskPS.h5
#             viewPS.py S1*PS.he5 displacement --subset-lalo 25.8759:25.8787,-80.1223:-80.1205 --ref-lalo 25.876026 -80.122124 --mask maskTempCoh.h5 --vlim -4 4
# 20240203:004542 * viewPS.py S1*PS.he5 displacement --subset-lalo 25.8759:25.8787,-80.1223:-80.1205 --ref-lalo 25.876026 -80.122124 --mask maskTempCoh.h5 --vlim -4 4
#             viewPS.py S1*PS.he5 displacement --subset-lalo 25.8759:25.8787,-80.1223:-80.1205 --vlim -3 3 --ref-lalo 25.87609 -80.12213 --geotiff ../../DEM/MiamiBeach.tif
# 20240203:004543 * viewPS.py S1*PS.he5 displacement --subset-lalo 25.8759:25.8787,-80.1223:-80.1205 --vlim -3 3 --ref-lalo 25.87609 -80.12213 --geotiff ../../DEM/MiamiBeach.tif
#             viewPS.py S1*PS.he5 elevation --subset-lalo 25.8759:25.8787,-80.1223:-80.1205
# 20240203:004543 * viewPS.py S1*PS.he5 elevation --subset-lalo 25.8759:25.8787,-80.1223:-80.1205
#             viewPS.py S1*PS.he5 dem_error --subset-lalo 25.8759:25.8787,-80.1223:-80.1205
# 20240203:004544 * viewPS.py S1*PS.he5 dem_error --subset-lalo 25.8759:25.8787,-80.1223:-80.1205
#             viewPS.py S1*PS.he5 velocity --subset-lalo 25.8759:25.8787,-80.1223:-80.1205 --vlim -0.6 0.6
# 20240203:004544 * viewPS.py S1*PS.he5 velocity --subset-lalo 25.8759:25.8787,-80.1223:-80.1205 --vlim -0.6 0.6
#             viewPS.py S1*PS.he5 velocity --subset-lalo 25.8759:25.8787,-80.1223:-80.1205 --backscatter
# 20240203:004545 * viewPS.py S1*PS.he5 velocity --subset-lalo 25.8759:25.8787,-80.1223:-80.1205 --backscatter
# Lat, Lon, y, x:  25.8759 -80.1223 897 1364
# Lat, Lon, y, x:  25.8787 -80.1205 916 1433
# Lat, Lon, y, x:  25.8759 -80.1205 894 1415
# Lat, Lon, y, x:  25.8787 -80.1205 916 1433
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       5 cmd=line.strip().split(' ')
#       6 sys.argv = cmd
# ----> 7 viewPS.main(sys.argv)
#
# File ~/code/rsmas_insar/tools/PlotData/src/plotdata/cli/viewPS.py:172, in main(iargs)
#     170 from plotdata.persistent_scatterers import persistent_scatterers
#     171 # run
# --> 172 persistent_scatterers(inps)
#
# File ~/code/rsmas_insar/tools/PlotData/src/plotdata/persistent_scatterers.py:162, in persistent_scatterers(inps)
#     159 def persistent_scatterers(inps):
#     160     # create kml file, display figure to screen, or save figure
# --> 162     update_input_namespace(inps)
#     164     fig, ax = configure_plot_settings(inps)
#     166     # create 2d or 3d kml file and exit
#
# File ~/code/rsmas_insar/tools/PlotData/src/plotdata/persistent_scatterers.py:128, in update_input_namespace(inps)
#     126 inps.xv = xmax - np.array(x[mask == 1])
#     127 inps.yv = np.array(y[mask == 1]) - ymin
# --> 128 backscatter_file = default_backscatter_file()
#     129 if not os.path.exists(inps.out_amplitude):
#     130     calculate_mean_amplitude(backscatter_file, inps.out_amplitude)
#
# File ~/code/rsmas_insar/tools/PlotData/src/plotdata/helper_functions_PS.py:51, in default_backscatter_file()
#      49         print(f'Using {option} for backscatter.')
#      50         return option
# ---> 51 raise FileNotFoundError(f'USER ERROR: No backscatter file found {options}.')
#
# FileNotFoundError: USER ERROR: No backscatter file found ['mean_amplitude.npy', '../inputs/slcStack.h5'].
