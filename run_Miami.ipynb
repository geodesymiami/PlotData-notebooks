# %% [markdown]
# ## Summary Miami
# This notebook demonstrates the examples of `viewPS.py`. For running, make sure you are working in a directory that has data.

# %%
import os
import sys
import plotdata.cli.viewPS as viewPS
from plotdata.cli.viewPS import EXAMPLE
# %load_ext autoreload
# %autoreload 2

# %%
lines = EXAMPLE.splitlines()
# print(EXAMPLE)
os.chdir(os.getenv('SCRATCHDIR') + '/MiamiSenAT48/miaplpy_MDCBeach_201601_202310/network_delaunay_4')
counter = 0
for line in lines[1:]:
    counter += 1
    line = line.strip()
    print(f"Example {counter}:\n{line}")

    cmd=line.strip().split(' ')
    sys.argv = cmd
    viewPS.main(sys.argv)
# Out:
# Example 1:
# viewPS.py S1*PS.he5 --subset-lalo 25.8759:25.8787,-80.1223:-80.1205
# 20240205:165342 * viewPS.py S1*PS.he5 --subset-lalo 25.8759:25.8787,-80.1223:-80.1205
# Example 2:
# viewPS.py S1*PS.he5 velocity --vlim -0.6 0.6
# 20240205:165359 * viewPS.py S1*PS.he5 velocity --vlim -0.6 0.6
# Example 3:
# viewPS.py S1*PS.he5 displacement --subset-lalo 25.8759:25.8787,-80.1223:-80.1205 --ref-lalo 25.876026 -80.122124
# 20240205:165402 * viewPS.py S1*PS.he5 displacement --subset-lalo 25.8759:25.8787,-80.1223:-80.1205 --ref-lalo 25.876026 -80.122124
# Example 4:
# viewPS.py S1*PS.he5 displacement --subset-lalo 25.8759:25.8787,-80.1223:-80.1205 --ref-lalo 25.876026 -80.122124 --mask ../maskPS.h5
# 20240205:165408 * viewPS.py S1*PS.he5 displacement --subset-lalo 25.8759:25.8787,-80.1223:-80.1205 --ref-lalo 25.876026 -80.122124 --mask ../maskPS.h5
# Example 5:
# ...
