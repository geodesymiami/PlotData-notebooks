# %%
import os
import sys
import plotdata.cli.viewPS as viewPS
import plotdata.cli.plot_data as plot_data
from mintpy.cli import tsview, view
from IPython.display import clear_output
os.chdir(os.getenv('SCRATCHDIR'))
# !pwd
# Out:
# /Users/giacomo/Library/CloudStorage/OneDrive-UniversityofMiami/scratch

# %% [markdown]
# ## Mintpy

# %%
# %%capture --no-display
# %tb
EXAMPLE='''
plot_data.py Chiles-CerroNegroSenDT142/mintpy Chiles-CerroNegroSenAT120/mintpy --plot-type velocity --dem Chiles-CerroNegroSenDT142/dem/Chiles-CerroNegro_dem.tif --mask-thresh 0.7 --vlim -3 3 --style scatter --scatter-size 2 --shade-exag 0.01
'''
lines = EXAMPLE.splitlines()
os.chdir(os.getenv('SCRATCHDIR'))
for line in lines[1:]:
    line = line.strip()
    cmd=line.strip().split(' ')
    sys.argv = cmd
    plot_data.main(sys.argv)

# %%
# %%capture --no-display
# %matplotlib widget
scratch = os.getenv('SCRATCHDIR')

ts_file = os.path.expanduser(scratch + '/Chiles-CerroNegroSenDT142/mintpy/S1_IW3_142_0591_0593_20170102_XXXXXXXX.he5')
cmd = f'{ts_file} --yx 135 190 --figsize 9 4 --dem {scratch}/Chiles-CerroNegroSenDT142/dem/Chiles-CerroNegro_dem.tif --shade-exag 0.01'
tsview.main(cmd.split())

# %%
# %%capture --no-display
# %matplotlib widget
scratch = os.getenv('SCRATCHDIR')

ts_file = os.path.expanduser(scratch + '/Chiles-CerroNegroSenAT120/mintpy/S1_IW2_120_1184_1185_20170112_XXXXXXXX.he5')
cmd = f'{ts_file} --yx 155 190 --figsize 9 4 --dem {scratch}/Chiles-CerroNegroSenDT142/dem/Chiles-CerroNegro_dem.tif --shade-exag 0.01'
tsview.main(cmd.split())

# %% [markdown]
# ## Miaplpy

# %%
# %%capture --no-display
# %tb
EXAMPLE='''
plot_data.py Chiles-CerroNegroSenDT142/miaplpy/network_delaunay Chiles-CerroNegroSenAT120/miaplpy/network_delaunay --plot-type velocity --dem Chiles-CerroNegroSenDT142/dem/Chiles-CerroNegro_dem.tif --mask-thresh 0.55 --style scatter --scatter-size 4 --shade-exag 0.01 --ref-lalo 0.83343 -77.96885

'''
lines = EXAMPLE.splitlines()
os.chdir(os.getenv('SCRATCHDIR'))
for line in lines[1:]:
    line = line.strip()
    cmd=line.strip().split(' ')
    sys.argv = cmd
    plot_data.main(sys.argv)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
# %%capture --no-display
# %matplotlib widget
scratch = os.getenv('SCRATCHDIR')

ts_file = os.path.expanduser(scratch + '/Chiles-CerroNegroSenDT142/miaplpy/network_delaunay/S1_IW3_142_0591_0593_20170102_XXXXXXXX.he5')
cmd = f'{ts_file} --yx 86 130 --figsize 9 4 --dem {scratch}/Chiles-CerroNegroSenDT142/dem/Chiles-CerroNegro_dem.tif --shade-exag 0.01'
tsview.main(cmd.split())

# %%
# %%capture --no-display
# %matplotlib widget
scratch = os.getenv('SCRATCHDIR')

ts_file = os.path.expanduser(scratch + '/Chiles-CerroNegroSenAT120/miaplpy/network_delaunay/S1_IW2_120_1184_1185_20170112_XXXXXXXX.he5')
cmd = f'{ts_file} --yx 86 150 --figsize 9 4 --dem {scratch}/Chiles-CerroNegroSenDT142/dem/Chiles-CerroNegro_dem.tif --shade-exag 0.01'
tsview.main(cmd.split())
